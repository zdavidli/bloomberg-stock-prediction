# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

import numpy as np
import csv

# %%
loss_128_64o = []
val_128_64o = []

with open('../csv/lstm128bs64o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_128_64o.append(float(row[0]))
        val_128_64o.append(float(row[1]))

loss_256_128o = []
val_256_128o = []

with open('../csv/lstm256bs128o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_256_128o.append(float(row[0]))
        val_256_128o.append(float(row[1]))

loss_64_16o = []
val_64_16o = []

with open('../csv/lstm64bs16o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_64_16o.append(float(row[0]))
        val_64_16o.append(float(row[1]))

loss_64_32o = []
val_64_32o = []

with open('../csv/lstm64bs32o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_64_32o.append(float(row[0]))
        val_64_32o.append(float(row[1]))

loss_128_64o_2 = []
val_128_64o_2 = []

with open('../csv/lstmx2.128bs64o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_128_64o_2.append(float(row[0]))
        val_128_64o_2.append(float(row[1]))

# %%
train = dict()
val = dict()
train['128_64o_2_pred1'] = []
val['128_64o_2_pred1'] = []

with open('../csv/LSTMx2.128bs64o400epochs+1.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred1'].append(float(row[0]))
        val['128_64o_2_pred1'].append(float(row[1]))

train['128_64o_2_pred2'] = []
val['128_64o_2_pred2'] = []

with open('../csv/LSTMx2.128bs64o400epochs+2.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred2'].append(float(row[0]))
        val['128_64o_2_pred2'].append(float(row[1]))
        
train['128_64o_2_pred3'] = []
val['128_64o_2_pred3'] = []

with open('../csv/LSTMx2.128bs64o400epochs+3.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred3'].append(float(row[0]))
        val['128_64o_2_pred3'].append(float(row[1]))

train['128_64o_2_pred4'] = []
val['128_64o_2_pred4'] = []

with open('../csv/LSTMx2.128bs64o400epochs+4.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred4'].append(float(row[0]))
        val['128_64o_2_pred4'].append(float(row[1]))
        
train['128_64o_2_pred8'] = []
val['128_64o_2_pred8'] = []

with open('../csv/LSTMx2.128bs64o400epochs+8.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred8'].append(float(row[0]))
        val['128_64o_2_pred8'].append(float(row[1]))

train['128_64o_2_pred16'] = []
val['128_64o_2_pred16'] = []

with open('../csv/LSTMx2.128bs64o400epochs+16.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred16'].append(float(row[0]))
        val['128_64o_2_pred16'].append(float(row[1]))

train['128_64o_2_pred32'] = []
val['128_64o_2_pred32'] = []

with open('../csv/LSTMx2.128bs64o400epochs+32.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred32'].append(float(row[0]))
        val['128_64o_2_pred32'].append(float(row[1]))

# %%
train['128_64o_2_pred1transfer'] = []
val['128_64o_2_pred1transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+1transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred1transfer'].append(float(row[0]))
        val['128_64o_2_pred1transfer'].append(float(row[1]))

train['128_64o_2_pred2transfer'] = []
val['128_64o_2_pred2transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+2transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred2transfer'].append(float(row[0]))
        val['128_64o_2_pred2transfer'].append(float(row[1]))
        
train['128_64o_2_pred3transfer'] = []
val['128_64o_2_pred3transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+3transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred3transfer'].append(float(row[0]))
        val['128_64o_2_pred3transfer'].append(float(row[1]))

train['128_64o_2_pred4transfer'] = []
val['128_64o_2_pred4transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+4transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred4transfer'].append(float(row[0]))
        val['128_64o_2_pred4transfer'].append(float(row[1]))
        
train['128_64o_2_pred8transfer'] = []
val['128_64o_2_pred8transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+8transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred8transfer'].append(float(row[0]))
        val['128_64o_2_pred8transfer'].append(float(row[1]))

train['128_64o_2_pred16transfer'] = []
val['128_64o_2_pred16transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+16transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred16transfer'].append(float(row[0]))
        val['128_64o_2_pred16transfer'].append(float(row[1]))

train['128_64o_2_pred32transfer'] = []
val['128_64o_2_pred32transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+32transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred32transfer'].append(float(row[0]))
        val['128_64o_2_pred32transfer'].append(float(row[1]))

# %%
train['64_32o_2_pred1'] = []
val['64_32o_2_pred1'] = []

with open('../csv/LSTMx2.64bs32o400epochs+1.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred1'].append(float(row[0]))
        val['64_32o_2_pred1'].append(float(row[1]))

train['64_32o_2_pred2'] = []
val['64_32o_2_pred2'] = []

with open('../csv/LSTMx2.64bs32o400epochs+2.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred2'].append(float(row[0]))
        val['64_32o_2_pred2'].append(float(row[1]))
        
train['64_32o_2_pred3'] = []
val['64_32o_2_pred3'] = []

with open('../csv/LSTMx2.64bs32o400epochs+3.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred3'].append(float(row[0]))
        val['64_32o_2_pred3'].append(float(row[1]))
        
                
train['64_32o_2_pred4'] = []
val['64_32o_2_pred4'] = []

with open('../csv/LSTMx2.64bs32o400epochs+4.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred4'].append(float(row[0]))
        val['64_32o_2_pred4'].append(float(row[1]))        
                
train['64_32o_2_pred8'] = []
val['64_32o_2_pred8'] = []

with open('../csv/LSTMx2.64bs32o400epochs+8.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred8'].append(float(row[0]))
        val['64_32o_2_pred8'].append(float(row[1]))

        
train['64_32o_2_pred16'] = []
val['64_32o_2_pred16'] = []

with open('../csv/LSTMx2.64bs32o400epochs+16.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred16'].append(float(row[0]))
        val['64_32o_2_pred16'].append(float(row[1]))
        
train['64_32o_2_pred32'] = []
val['64_32o_2_pred32'] = []

with open('../csv/LSTMx2.64bs32o400epochs+32.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred32'].append(float(row[0]))
        val['64_32o_2_pred32'].append(float(row[1]))

# %%
train['64_32o_2_pred1transfer'] = []
val['64_32o_2_pred1transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+1transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred1transfer'].append(float(row[0]))
        val['64_32o_2_pred1transfer'].append(float(row[1]))

train['64_32o_2_pred2transfer'] = []
val['64_32o_2_pred2transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+2transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred2transfer'].append(float(row[0]))
        val['64_32o_2_pred2transfer'].append(float(row[1]))
        
train['64_32o_2_pred3transfer'] = []
val['64_32o_2_pred3transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+3transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred3transfer'].append(float(row[0]))
        val['64_32o_2_pred3transfer'].append(float(row[1]))
        
                
train['64_32o_2_pred4transfer'] = []
val['64_32o_2_pred4transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+4transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred4transfer'].append(float(row[0]))
        val['64_32o_2_pred4transfer'].append(float(row[1]))        
                
train['64_32o_2_pred8transfer'] = []
val['64_32o_2_pred8transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+8transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred8transfer'].append(float(row[0]))
        val['64_32o_2_pred8transfer'].append(float(row[1]))

        
train['64_32o_2_pred16transfer'] = []
val['64_32o_2_pred16transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+16transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred16transfer'].append(float(row[0]))
        val['64_32o_2_pred16transfer'].append(float(row[1]))
        
train['64_32o_2_pred32transfer'] = []
val['64_32o_2_pred32transfer'] = []

with open('../csv/LSTMx2.64bs32o400epochs+32transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_32o_2_pred32transfer'].append(float(row[0]))
        val['64_32o_2_pred32transfer'].append(float(row[1]))

# %%
train['128_0o_2_pred1'] = []
val['128_0o_2_pred1'] = []

with open('../csv/LSTMx2.128bs0o400epochs+1.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred1'].append(float(row[0]))
        val['128_0o_2_pred1'].append(float(row[1]))

train['128_0o_2_pred2'] = []
val['128_0o_2_pred2'] = []

with open('../csv/LSTMx2.128bs0o400epochs+2.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred2'].append(float(row[0]))
        val['128_0o_2_pred2'].append(float(row[1]))
        
train['128_0o_2_pred3'] = []
val['128_0o_2_pred3'] = []

with open('../csv/LSTMx2.128bs0o400epochs+3.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred3'].append(float(row[0]))
        val['128_0o_2_pred3'].append(float(row[1]))
        
                
train['128_0o_2_pred4'] = []
val['128_0o_2_pred4'] = []

with open('../csv/LSTMx2.128bs0o400epochs+4.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred4'].append(float(row[0]))
        val['128_0o_2_pred4'].append(float(row[1]))        
                
train['128_0o_2_pred8'] = []
val['128_0o_2_pred8'] = []

with open('../csv/LSTMx2.128bs0o400epochs+8.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred8'].append(float(row[0]))
        val['128_0o_2_pred8'].append(float(row[1]))

        
train['128_0o_2_pred16'] = []
val['128_0o_2_pred16'] = []

with open('../csv/LSTMx2.128bs0o400epochs+16.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred16'].append(float(row[0]))
        val['128_0o_2_pred16'].append(float(row[1]))
        
train['128_0o_2_pred32'] = []
val['128_0o_2_pred32'] = []

with open('../csv/LSTMx2.128bs0o400epochs+32.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_0o_2_pred32'].append(float(row[0]))
        val['128_0o_2_pred32'].append(float(row[1]))

# %%
train['64_0o_2_pred1'] = []
val['64_0o_2_pred1'] = []

with open('../csv/LSTMx2.64bs0o400epochs+1.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred1'].append(float(row[0]))
        val['64_0o_2_pred1'].append(float(row[1]))

train['64_0o_2_pred2'] = []
val['64_0o_2_pred2'] = []

with open('../csv/LSTMx2.64bs0o400epochs+2.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred2'].append(float(row[0]))
        val['64_0o_2_pred2'].append(float(row[1]))
        
train['64_0o_2_pred3'] = []
val['64_0o_2_pred3'] = []

with open('../csv/LSTMx2.64bs0o400epochs+3.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred3'].append(float(row[0]))
        val['64_0o_2_pred3'].append(float(row[1]))
        
                
train['64_0o_2_pred4'] = []
val['64_0o_2_pred4'] = []

with open('../csv/LSTMx2.64bs0o400epochs+4.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred4'].append(float(row[0]))
        val['64_0o_2_pred4'].append(float(row[1]))        
                
train['64_0o_2_pred8'] = []
val['64_0o_2_pred8'] = []

with open('../csv/LSTMx2.64bs0o400epochs+8.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred8'].append(float(row[0]))
        val['64_0o_2_pred8'].append(float(row[1]))

        
train['64_0o_2_pred16'] = []
val['64_0o_2_pred16'] = []

with open('../csv/LSTMx2.64bs0o400epochs+16.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred16'].append(float(row[0]))
        val['64_0o_2_pred16'].append(float(row[1]))
        
train['64_0o_2_pred32'] = []
val['64_0o_2_pred32'] = []

with open('../csv/LSTMx2.64bs0o400epochs+32.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred32'].append(float(row[0]))
        val['64_0o_2_pred32'].append(float(row[1]))

# %%
train['64_0o_2_pred1'] = []
val['64_0o_2_pred1'] = []

with open('../csv/LSTMx2.64bs0o400epochs+1.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred1'].append(float(row[0]))
        val['64_0o_2_pred1'].append(float(row[1]))

train['64_0o_2_pred2'] = []
val['64_0o_2_pred2'] = []

with open('../csv/LSTMx2.64bs0o400epochs+2.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred2'].append(float(row[0]))
        val['64_0o_2_pred2'].append(float(row[1]))
        
train['64_0o_2_pred3'] = []
val['64_0o_2_pred3'] = []

with open('../csv/LSTMx2.64bs0o400epochs+3.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred3'].append(float(row[0]))
        val['64_0o_2_pred3'].append(float(row[1]))
        
                
train['64_0o_2_pred4'] = []
val['64_0o_2_pred4'] = []

with open('../csv/LSTMx2.64bs0o400epochs+4.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred4'].append(float(row[0]))
        val['64_0o_2_pred4'].append(float(row[1]))        
                
train['64_0o_2_pred8'] = []
val['64_0o_2_pred8'] = []

with open('../csv/LSTMx2.64bs0o400epochs+8.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred8'].append(float(row[0]))
        val['64_0o_2_pred8'].append(float(row[1]))

        
train['64_0o_2_pred16'] = []
val['64_0o_2_pred16'] = []

with open('../csv/LSTMx2.64bs0o400epochs+16.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred16'].append(float(row[0]))
        val['64_0o_2_pred16'].append(float(row[1]))
        
train['64_0o_2_pred32'] = []
val['64_0o_2_pred32'] = []

with open('../csv/LSTMx2.64bs0o400epochs+32.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['64_0o_2_pred32'].append(float(row[0]))
        val['64_0o_2_pred32'].append(float(row[1]))

# %%
train['layer2_hidden_100ep_seq2seq'] = []
val['layer2_hidden_100ep_seq2seq'] = []

with open('../csv/layer-2_hidden-100_epoch-1000_seq2seq.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['layer2_hidden_100ep_seq2seq'].append(float(row[0]))
        val['layer2_hidden_100ep_seq2seq'].append(float(row[1]))
        
train['layer3_hidden_400ep_seq2seq'] = []
val['layer3_hidden_400ep_seq2seq'] = []

with open('../csv/layer-3_hidden-400_epoch-600_seq2seq.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['layer3_hidden_400ep_seq2seq'].append(float(row[0]))
        val['layer3_hidden_400ep_seq2seq'].append(float(row[1]))

# %% [markdown]
# 128 window and 0 overlap

# %%
plt.figure(figsize=(10, 6))
plt.title('Loss without transfer learning\nWindow Size 128, Overlap 0')
plt.plot(train['128_0o_2_pred1'], color='tab:blue', label='1 min')
plt.plot(train['128_0o_2_pred2'], color='tab:orange', label='2 min')
plt.plot(train['128_0o_2_pred3'], color='tab:green', label='3 min')
plt.plot(train['128_0o_2_pred4'], color='tab:red', label='4 min')
plt.plot(val['128_0o_2_pred1'], color='tab:blue', ls='dashed', label='1 min')
plt.plot(val['128_0o_2_pred2'], color='tab:orange', ls='dashed', label='2 min')
plt.plot(val['128_0o_2_pred3'], color='tab:green', ls='dashed', label='3 min')
plt.plot(val['128_0o_2_pred4'], color='tab:red', ls='dashed',label='4 min')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/pred_future_no_transfer_128window_0overlap.pdf')

# %% [markdown]
# 64 window and 0 overlap

# %%
plt.figure(figsize=(10, 6))
plt.title('Loss without transfer learning\nWindow Size 64, Overlap 0')
plt.plot(train['64_0o_2_pred1'], color='tab:blue', label='1 min')
plt.plot(train['64_0o_2_pred2'], color='tab:orange', label='2 min')
plt.plot(train['64_0o_2_pred3'], color='tab:green', label='3 min')
plt.plot(train['64_0o_2_pred4'], color='tab:red', label='4 min')
plt.plot(val['64_0o_2_pred1'], color='tab:blue', ls='dashed', label='1 min')
plt.plot(val['64_0o_2_pred2'], color='tab:orange', ls='dashed', label='2 min')
plt.plot(val['64_0o_2_pred3'], color='tab:green', ls='dashed', label='3 min')
plt.plot(val['64_0o_2_pred4'], color='tab:red', ls='dashed',label='4 min')
# plt.plot(train['64_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['64_64o_2_pred16'], label='Predicting 16')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/pred_future_no_transfer_64window_0overlap.pdf')

# %% [markdown]
# 128 window and 64 overlap

# %%
plt.figure(figsize=(10, 6))
plt.title('Loss without transfer learning\nWindow Size 128, Overlap 64')
plt.plot(train['128_64o_2_pred1'], color='tab:blue', label='1 min')
plt.plot(train['128_64o_2_pred2'], color='tab:orange', label='2 min')
plt.plot(train['128_64o_2_pred3'], color='tab:green', label='3 min')
plt.plot(train['128_64o_2_pred4'], color='tab:red', label='4 min')
plt.plot(val['128_64o_2_pred1'], color='tab:blue', ls='dashed', label='1 min')
plt.plot(val['128_64o_2_pred2'], color='tab:orange', ls='dashed', label='2 min')
plt.plot(val['128_64o_2_pred3'], color='tab:green', ls='dashed', label='3 min')
plt.plot(val['128_64o_2_pred4'], color='tab:red', ls='dashed',label='4 min')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/pred_future_no_transfer_128window.pdf')

# %%
plt.figure(figsize=(10,6))
plt.title('Loss with transfer learning\nWindow Size 128, Overlap 64')
plt.plot(train['128_64o_2_pred1transfer'], color='tab:blue', label='1 min')
plt.plot(train['128_64o_2_pred2transfer'], color='tab:orange', label='2 min')
plt.plot(train['128_64o_2_pred3transfer'], color='tab:green', label='3 min')
plt.plot(train['128_64o_2_pred4transfer'], color='tab:red', label='4 min')
plt.plot(val['128_64o_2_pred1transfer'], color='tab:blue', ls='dashed', label='1 min')
plt.plot(val['128_64o_2_pred2transfer'], color='tab:orange', ls='dashed', label='2 min')
plt.plot(val['128_64o_2_pred3transfer'], color='tab:green', ls='dashed', label='3 min')
plt.plot(val['128_64o_2_pred4transfer'], color='tab:red', ls='dashed',label='4 min')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
# plt.legend(bbox_to_anchor=(1, 1))
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/pred_future_transfer_128window.pdf')

# %% [markdown]
# 64 window and 32 overlap

# %%
plt.figure(figsize=(10, 6))
plt.title('Loss without transfer learning\nWindow Size 64, Overlap 32')
plt.plot(train['64_32o_2_pred1'], color='tab:blue', label='1 min')
plt.plot(train['64_32o_2_pred2'], color='tab:orange', label='2 min')
# plt.plot(train['64_32o_2_pred3'], color='tab:green', label='3 min')
# plt.plot(train['64_32o_2_pred4'], color='tab:red', label='4 min')
plt.plot(val['64_32o_2_pred1'], color='tab:blue', ls='dashed', label='1 min')
plt.plot(val['64_32o_2_pred2'], color='tab:orange', ls='dashed', label='2 min')
# plt.plot(val['64_32o_2_pred3'], color='tab:green', ls='dashed', label='3 min')
# plt.plot(val['64_32o_2_pred4'], color='tab:red', ls='dashed',label='4 min')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/pred_future_no_transfer_64window.pdf')

# %%
plt.figure(figsize=(10, 6))
plt.title('Loss with transfer learning\nWindow Size 64, Overlap 32')
plt.plot(train['64_32o_2_pred1transfer'], color='tab:blue', label='1 min')
plt.plot(train['64_32o_2_pred2transfer'], color='tab:orange', label='2 min')
# plt.plot(train['64_32o_2_pred3transfer'], color='tab:green', label='3 min')
# plt.plot(train['64_32o_2_pred4transfer'], color='tab:red', label='4 min')
plt.plot(val['64_32o_2_pred1transfer'], color='tab:blue', ls='dashed', label='1 min')
plt.plot(val['64_32o_2_pred2transfer'], color='tab:orange', ls='dashed', label='2 min')
# plt.plot(val['64_32o_2_pred3transfer'], color='tab:green', ls='dashed', label='3 min')
# plt.plot(val['64_32o_2_pred4transfer'], color='tab:red', ls='dashed',label='4 min')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/pred_future_transfer_64window.pdf')

# %%
plt.figure(figsize=(10, 6))
plt.title('Sequence to Sequence Loss')
plt.plot(train['layer2_hidden_100ep_seq2seq'][3:603], color='tab:blue', label='2 Layers, 64 Hidden Units')
plt.plot(val['layer2_hidden_100ep_seq2seq'][3:603], color='tab:blue', ls='dashed', label='2 Layers, 64 Hidden Units')
plt.plot(train['layer3_hidden_400ep_seq2seq'][3:603], color='tab:orange', label='3 Layers, 400 Hidden Units')
plt.plot(val['layer3_hidden_400ep_seq2seq'][3:603], color='tab:orange', ls='dashed', label='3 Layers, 400 Hidden Units')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Epoch')
plt.ylabel('Normalized MSE')
plt.savefig('../figures/seq2seq_loss.pdf')

# %%
x128_64o = [train['128_64o_2_pred1'][-1], train['128_64o_2_pred2'][-1], train['128_64o_2_pred3'][-1], train['128_64o_2_pred4'][-1], train['128_64o_2_pred8'][-1], train['128_64o_2_pred16'][-1], train['128_64o_2_pred32'][-1]]
x128_0o = [train['128_0o_2_pred1'][-1], train['128_0o_2_pred2'][-1], train['128_0o_2_pred3'][-1], train['128_0o_2_pred4'][-1], train['128_0o_2_pred8'][-1], train['128_0o_2_pred16'][-1], train['128_0o_2_pred32'][-1]]
x64_32o = [train['64_32o_2_pred1'][-1], train['64_32o_2_pred2'][-1], train['64_32o_2_pred3'][-1], train['64_32o_2_pred4'][-1], train['64_32o_2_pred8'][-1], train['64_32o_2_pred16'][-1], train['64_32o_2_pred32'][-1]]
x64_0o = [train['64_0o_2_pred1'][-1], train['64_0o_2_pred2'][-1], train['64_0o_2_pred3'][-1], train['64_0o_2_pred4'][-1], train['64_0o_2_pred8'][-1], train['64_0o_2_pred16'][-1], train['64_0o_2_pred32'][-1]]
x128_64otransfer = [train['128_64o_2_pred1transfer'][-1], train['128_64o_2_pred2transfer'][-1], train['128_64o_2_pred3transfer'][-1], train['128_64o_2_pred4transfer'][-1], train['128_64o_2_pred8transfer'][-1], train['128_64o_2_pred16transfer'][-1], train['128_64o_2_pred32transfer'][-1]]
x64_32otransfer = [train['64_32o_2_pred1transfer'][-1], train['64_32o_2_pred2transfer'][-1], train['64_32o_2_pred3transfer'][-1], train['64_32o_2_pred4transfer'][-1], train['64_32o_2_pred8transfer'][-1], train['64_32o_2_pred16transfer'][-1], train['64_32o_2_pred32transfer'][-1]]

baseline = [0.00010486644179269067,
0.0004150467442441954,
0.0006012048243338282,
0.0006704292320124004,
0.0009693418880635628,
0.0013600104748491455,
0.002356043749606695]

y = [1,2,3,4,8,16,32]

# %%
plt.figure(figsize=(10, 6))
plt.plot(y, x128_64o, label='Window 128, Overlap 64')
plt.plot(y, x128_0o, label='Window 128, Overlap 0')
plt.plot(y, x64_32o, label='Window 64, Overlap 32')
plt.plot(y, x64_0o, label='Window 64, Overlap 0')
plt.plot(y, x128_64otransfer, ls='--', label='Window 128, Overlap 64, Cascaded')
plt.plot(y, x64_32otransfer, ls='--', label='Window 64, Overlap 32, Cascaded')
plt.plot(y, baseline, c='k', label='Baseline')
plt.xlabel(r't+k minute prediction')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.gca().set_xscale('log', basex=2)
plt.gca().set_yscale('log', basey=2)
plt.title('Accuracy vs Prediction Distance k')
plt.savefig('../figures/prediction_dist_accuracy.pdf')
