# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

import numpy as np
import csv

# %%
loss_128_64o = []
val_128_64o = []

with open('../csv/lstm128bs64o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_128_64o.append(float(row[0]))
        val_128_64o.append(float(row[1]))

loss_256_128o = []
val_256_128o = []

with open('../csv/lstm256bs128o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_256_128o.append(float(row[0]))
        val_256_128o.append(float(row[1]))

loss_64_16o = []
val_64_16o = []

with open('../csv/lstm64bs16o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_64_16o.append(float(row[0]))
        val_64_16o.append(float(row[1]))

loss_64_32o = []
val_64_32o = []

with open('../csv/lstm64bs32o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_64_32o.append(float(row[0]))
        val_64_32o.append(float(row[1]))

loss_128_64o_2 = []
val_128_64o_2 = []

with open('../csv/lstmx2.128bs64o.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        loss_128_64o_2.append(float(row[0]))
        val_128_64o_2.append(float(row[1]))

# %%
train = dict()
val = dict()
train['128_64o_2_pred1'] = []
val['128_64o_2_pred1'] = []

with open('../csv/LSTMx2.128bs64o400epochs+1.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred1'].append(float(row[0]))
        val['128_64o_2_pred1'].append(float(row[1]))

train['128_64o_2_pred2'] = []
val['128_64o_2_pred2'] = []

with open('../csv/LSTMx2.128bs64o400epochs+2.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred2'].append(float(row[0]))
        val['128_64o_2_pred2'].append(float(row[1]))
        
train['128_64o_2_pred3'] = []
val['128_64o_2_pred3'] = []

with open('../csv/LSTMx2.128bs64o400epochs+3.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred3'].append(float(row[0]))
        val['128_64o_2_pred3'].append(float(row[1]))

train['128_64o_2_pred4'] = []
val['128_64o_2_pred4'] = []

with open('../csv/LSTMx2.128bs64o400epochs+4.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred4'].append(float(row[0]))
        val['128_64o_2_pred4'].append(float(row[1]))
        
train['128_64o_2_pred8'] = []
val['128_64o_2_pred8'] = []

with open('../csv/LSTMx2.128bs64o400epochs+8.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred8'].append(float(row[0]))
        val['128_64o_2_pred8'].append(float(row[1]))

train['128_64o_2_pred16'] = []
val['128_64o_2_pred16'] = []

with open('../csv/LSTMx2.128bs64o400epochs+16.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred16'].append(float(row[0]))
        val['128_64o_2_pred16'].append(float(row[1]))

train['128_64o_2_pred32'] = []
val['128_64o_2_pred32'] = []

with open('../csv/LSTMx2.128bs64o400epochs+32.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred32'].append(float(row[0]))
        val['128_64o_2_pred32'].append(float(row[1]))

# %%
# train = dict()
# val = dict()
train['128_64o_2_pred1transfer'] = []
val['128_64o_2_pred1transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+1transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred1transfer'].append(float(row[0]))
        val['128_64o_2_pred1transfer'].append(float(row[1]))

train['128_64o_2_pred2transfer'] = []
val['128_64o_2_pred2transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+2transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred2transfer'].append(float(row[0]))
        val['128_64o_2_pred2transfer'].append(float(row[1]))
        
train['128_64o_2_pred3transfer'] = []
val['128_64o_2_pred3transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+3transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred3transfer'].append(float(row[0]))
        val['128_64o_2_pred3transfer'].append(float(row[1]))

train['128_64o_2_pred4transfer'] = []
val['128_64o_2_pred4transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+4transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred4transfer'].append(float(row[0]))
        val['128_64o_2_pred4transfer'].append(float(row[1]))
        
train['128_64o_2_pred8transfer'] = []
val['128_64o_2_pred8transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+8transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred8transfer'].append(float(row[0]))
        val['128_64o_2_pred8transfer'].append(float(row[1]))

train['128_64o_2_pred16transfer'] = []
val['128_64o_2_pred16transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+16transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred16transfer'].append(float(row[0]))
        val['128_64o_2_pred16transfer'].append(float(row[1]))

train['128_64o_2_pred32transfer'] = []
val['128_64o_2_pred32transfer'] = []

with open('../csv/LSTMx2.128bs64o400epochs+32transfer.csv', 'r') as f:
    r = csv.reader(f)
    for row in r:
        train['128_64o_2_pred32transfer'].append(float(row[0]))
        val['128_64o_2_pred32transfer'].append(float(row[1]))

# %%
# train['adam1e-4'] = []
# val['adam1e-4'] = []

# with open('../csv/lstmx2adameps-4.128bs64o.csv', 'r') as f:
#     r = csv.reader(f)
#     for row in r:
#         train['adam1e-4'].append(float(row[0]))
#         val['adam1e-4'].append(float(row[1]))
        
# train['adam1e-6'] = []
# val['adam1e-6'] = []

# with open('../csv/lstmx2adameps-6.128bs64o.csv', 'r') as f:
#     r = csv.reader(f)
#     for row in r:
#         train['adam1e-6'].append(float(row[0]))
#         val['adam1e-6'].append(float(row[1]))
        
# train['adam1e-6'] = []
# val['adam1e-6'] = []

# with open('../csv/lstmx2adameps-6.128bs64o.csv', 'r') as f:
#     r = csv.reader(f)
#     for row in r:
#         train['adam1e-6'].append(float(row[0]))
#         val['adam1e-6'].append(float(row[1]))

# %%
plt.figure()
plt.plot(train['128_64o_2_pred1'], label='Predicting 1 future minute')
plt.plot(train['128_64o_2_pred2'], label='Predicting 2 future minutes')
plt.plot(train['128_64o_2_pred3'], label='Predicting 3 future minutes')
plt.plot(train['128_64o_2_pred4'], label='Predicting 4 future minutes')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
plt.title('Training Loss')
plt.legend()
plt.savefig('../figures/pred_future.svg')

# %%
plt.figure()
plt.title('Training Loss with transfer learning')
plt.plot(train['128_64o_2_pred1transfer'], label='Predicting 1')
plt.plot(train['128_64o_2_pred2transfer'], label='Predicting 2')
plt.plot(train['128_64o_2_pred3transfer'], label='Predicting 3')
plt.plot(train['128_64o_2_pred4transfer'], label='Predicting 4')
# plt.plot(train['128_64o_2_pred8'], label='Predicting 8')
# plt.plot(train['128_64o_2_pred16'], label='Predicting 16')
plt.legend()

# %%
plt.figure()
plt.title('Training Loss')
plt.plot(loss_64_16o, label='Window Size 64, Overlap 16')
plt.plot(loss_64_32o, label='Window Size 64, Overlap 32')
plt.plot(loss_128_64o, label='Window Size 128, Overlap 64')
plt.plot(loss_256_128o, label='Window Size 256, Overlap 128')
plt.legend()

# %%
plt.figure()
plt.title('Validation Loss')
plt.plot(val_64_16o, label='Window Size 64, Overlap 16')
plt.plot(val_64_32o, label='Window Size 64, Overlap 32')
plt.plot(val_128_64o, label='Window Size 128, Overlap 64')
plt.plot(val_256_128o, label='Window Size 256, Overlap 128')
plt.legend()

# %%
plt.figure()
plt.title('Training Loss')
plt.plot(loss_128_64o_2, label='Window Size 128, Overlap 64, 2-Layer LSTM')
plt.legend()
